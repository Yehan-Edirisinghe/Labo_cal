# %%
import numpy as np
import matplotlib.pyplot as plt
import stats
from scipy.stats import norm
from functions import max_sez_aurea as maxa
from iminuit import Minuit
from iminuit.cost import ExtendedUnbinnedNLL,LeastSquares

# %%
def parab(x,a,b,c):
    x = np.array(x)
    return a*np.power(x,2) + b*np.array(x) + c

# %%
def gauss(x,mu,sigma):
    return stats.toy_Gauss().normal(mu,sigma)

# %%
def f(x,a,b,c,mu,sigma):
    return parab(x,a,b,c) + 2*norm.pdf(x,mu,sigma)

# %%
def f2(x,a,b,c):
    return parab(x,a,b,c)

# %%
a, b, c = -0.2, 0.8, 1
mu, sigma = 2, 0.25

# %%
x = np.linspace(-1,5,200)
y = [f(x,a,b,c,mu,sigma) for x in x]
plt.plot(x,y)
plt.show()

# %%
xmax,ymax = maxa(f, -1.5,5, a,b,c,mu,sigma)
print("x = ",xmax,"y = ",ymax)
# Out:
# x =  1.999980275409694 y =  4.991538233200065

# %%
def try_catch(f,xmin,xmax,fmax,N,*args):
    data = []
    counter = 0
    for i in range(N):
        x = np.random.uniform(xmin,xmax)
        y = np.random.uniform(0,fmax)
        if f(x,*args) > y:
            data.append(x)
            counter +=1
    p = counter/N
    A = (xmax-xmin)*fmax
    return data

# %%
data = try_catch(f,-1,5,ymax,5000,a,b,c,mu,sigma)
bin_content, bin_edges, boh = plt.hist(data,bins=20)
plt.show()

# %%
#data2 = try_catch(f2,-1,5,maxa(f2,-1.5,5,a,b,c)[1],1000,a,b,c)
#bin_content, bin_edges, boh = plt.hist(data2,bins=20)
#plt.show()

# %%
yerr= 0.1*np.ones(len(bin_content))

cost = LeastSquares(bin_edges[1:],bin_content,yerr,f)
my_minuit = Minuit(cost, a=-0.2, b=0.8, c=1,mu=2,sigma=.3)
#my_minuit = Minuit(cost,a=-0.2, b=0.8,c=1 )

my_minuit.migrad()
my_minuit.hesse()
display(my_minuit)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 1.312e+07 (χ²/ndof = 874538.6)│              Nfcn = 306              │
# │ EDM = 1.25e+08 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   ABOVE EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │     Covariance FORCED pos. def.      │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬───────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name  │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼───────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a     │  -0.2000  │  0.0011   │            │            │         │         │       │
# │ 1 │ b     │   0.800   │   0.005   │            │            │         │         │       │
# │ 2 │ c     │   1.000   │   0.015   │            │            │         │         │       │
# │ 3 │ mu    │  2.0000   │  0.0004   │            │            │         │         │       │
# │ 4 │ sigma │  19.6e-3  │  0.5e-3   │            │            │         │         │       │
# └───┴───────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───────┬──────────────────────────────────────────────┐
# │       │        a        b        c       mu    sigma │
# ├───────┼──────────────────────────────────────────────┤
# │     a │ 1.23e-06  -0.9e-6  -1.0e-6  0.03e-6  0.04e-6 │
# │     b │  -0.9e-6  2.3e-05 0.010e-3  0.73e-6  1.00e-6 │
# │     c │  -1.0e-6 0.010e-3  0.00022  3.30e-6  4.51e-6 │
# │    mu │  0.03e-6  0.73e-6  3.30e-6 1.31e-07  0.18e-6 │
# │ sigma │  0.04e-6  1.00e-6  4.51e-6  0.18e-6 2.43e-07 │
# └───────┴──────────────────────────────────────────────┘
