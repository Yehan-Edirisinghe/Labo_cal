# %%
import numpy as np
import matplotlib.pyplot as plt
from stats import *

# %%
def fact(x):
    res = 1
    for i in range(x):
        res *= x-i
    return res

# %%
def f(x,l):
    
    return -np.power(l,x)*np.exp(-l)/fact(x)

# %%
a = f(1,5)

# %%
y = toy_Poiss(5,3,1000).generate()
m,v,s,k = stat(y)
print(m,v,s,k,sep='\n')
plt.hist(y)
plt.show()
# Out:
# 5.851112467965026
# 4.281595049851141
# 2.3175256032460085
# 8.450406632139732
