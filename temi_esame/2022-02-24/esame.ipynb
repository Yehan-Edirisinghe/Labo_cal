# %%
import numpy as np
import matplotlib.pyplot as plt
from stats import *
from fit import*

# %%
def fact(x):
    res = 1
    for i in range(x):
        res *= x-i
    return res

# %%
def f(x,l):
    
    return -np.power(l,x)*np.exp(-l)/fact(x)

# %%
data = toy_Poiss(5,N=1000).generate()
m,v,s,k = stat(data)
print(m,v,s,k,sep='\n')
plt.hist(data,density=True)
plt.show()
# Out:
# 4.916
# 2.189279333479395
# 0.3991771632165802
# 0.04021814216773212

# %% [markdown]
# Si generi un campione di 10 numeri pseudo-casuali distribuiti in modo Poissoniano e per ciascuno
# di essi si calcoli la probabilità che quel numero sia stato generato a partire dal valore di λ = 3

# %%
lam = 3
data_10 = toy_Poiss(lam,N=10).generate()
ML = [likelihood(f,data_10,3) for x in range(10)]
plt.scatter(range(10),ML)

# %% [markdown]
# Si scriva una funzione che calcoli il valore della likelihood del campione generato e se ne stampi il
# valore a schermo per i valori interi di λ compresi fra 1 e 5
