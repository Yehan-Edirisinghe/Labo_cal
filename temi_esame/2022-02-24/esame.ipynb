# %%
import numpy as np
import matplotlib.pyplot as plt
from stats import *

# %%
def fact(x):
    res = 1
    for i in range(x):
        res *= x-i
    return res

# %%
def f(x,l):
    
    return -np.power(l,x)*np.exp(-l)/fact(x)

# %%
a = f(1,5)

# %%
y = toy_Poiss(5,3,1000).generate()
m,v,s,k = stat(y)
print(m,v,s,k,sep='\n')
plt.hist(y)
plt.show()
# Out:
# 58.219
# 56.27789120960378
# 1.7685068283786751
# 3.9245230556463584
